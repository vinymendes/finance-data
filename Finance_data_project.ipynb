# %% [markdown]
# <a href="https://colab.research.google.com/github/vinymendes/finance-data/blob/main/Finance_data_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import yfinance as yf
import matplotlib.pyplot as plt
from pandas_datareader import data, wb
import datetime
# %matplotlib inline

# %%
df = pd.read_pickle('/content/all_banks')

# %%
df.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %%
df['BAC']
# Out:
# Stock Info   Open   High    Low  Close    Volume
# Date
# 2006-01-03  46.92  47.18  46.15  47.08  16296700
# 2006-01-04  47.00  47.24  46.45  46.58  17757900
# 2006-01-05  46.58  46.83  46.32  46.64  14970900
# 2006-01-06  46.80  46.91  46.35  46.57  12599800
# 2006-01-09  46.72  46.97  46.36  46.60  15620000
# ...           ...    ...    ...    ...       ...
# 2015-12-24  17.32  17.38  17.22  17.27  29373415
# 2015-12-28  17.22  17.23  16.98  17.13  41777497
# 2015-12-29  17.25  17.35  17.16  17.28  45670376
# 2015-12-30  17.20  17.24  17.04  17.05  35066378
# 2015-12-31  17.01  17.07  16.83  16.83  47152968
#
# [2517 rows x 5 columns]

# %%
# !pip show pandas_datareader
# Out:
# Name: pandas-datareader
# Version: 0.10.0
# Summary: Data readers extracted from the pandas codebase,should be compatible with recent pandas versions
# Home-page: https://github.com/pydata/pandas-datareader
# Author: The PyData Development Team
# Author-email: pydata@googlegroups.com
# License: BSD License
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: lxml, pandas, requests
# Required-by:

# %%
start = datetime.datetime(2006, 1, 1)
end = datetime.datetime(2016, 1, 1)

# %%
BAC = yf.download('BAC', start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
BAC.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  31.750559  16296700
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  31.413370  17757900
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  31.453825  14970700
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  31.406618  12599800
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  31.426861  15619400

# %%
C = yf.download('C', start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
C.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2006-01-03  490.000000  493.799988  481.100006  492.899994  332.317108
# 2006-01-04  488.600006  491.000000  483.500000  483.799988  326.181641
# 2006-01-05  484.399994  487.799988  484.000000  486.200012  327.799805
# 2006-01-06  488.799988  489.000000  482.000000  486.200012  327.799805
# 2006-01-09  486.000000  487.399994  483.000000  483.899994  326.249176
#
#              Volume
# Date
# 2006-01-03  1537600
# 2006-01-04  1870960
# 2006-01-05  1143160
# 2006-01-06  1370210
# 2006-01-09  1680740

# %%
GS = yf.download('GS', start, end)
JPM = yf.download('JPM', start, end)
MS = yf.download('MS', start, end)
WFC = yf.download('WFC', start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
GS
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 
['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
bank_stocks = pd.concat([BAC, C, GS, JPM, MS, WFC], axis=1, keys=tickers)

# %%
bank_stocks.head()
# Out:
#                   BAC                                                        \
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  31.750559  16296700
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  31.413370  17757900
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  31.453825  14970700
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  31.406618  12599800
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  31.426861  15619400
#
#                      C                                      ...         MS  \
#                   Open        High         Low       Close  ...        Low
# Date                                                        ...
# 2006-01-03  490.000000  493.799988  481.100006  492.899994  ...  56.740002
# 2006-01-04  488.600006  491.000000  483.500000  483.799988  ...  58.349998
# ...

# %%
bank_stocks.columns.names = ['Bank Ticker', 'Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                                        \
# Stock Info        Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03   46.919998  47.180000  46.150002  47.080002  31.750559  16296700
# 2006-01-04   47.000000  47.240002  46.450001  46.580002  31.413370  17757900
# 2006-01-05   46.580002  46.830002  46.320000  46.639999  31.453825  14970700
# 2006-01-06   46.799999  46.910000  46.349998  46.570000  31.406618  12599800
# 2006-01-09   46.720001  46.970001  46.360001  46.599998  31.426861  15619400
#
# Bank Ticker           C                                      ...         MS  \
# Stock Info         Open        High         Low       Close  ...        Low
# Date                                                         ...
# 2006-01-03   490.000000  493.799988  481.100006  492.899994  ...  56.740002
# 2006-01-04   488.600006  491.000000  483.500000  483.799988  ...  58.349998
# ...

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick+' Return'] = bank_stocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158

# %%
sns.pairplot(returns[1:])

# %%
returns.min()
# Out:
# BAC Return   -0.289694
# C Return     -0.390244
# GS Return    -0.189596
# JPM Return   -0.207274
# MS Return    -0.258929
# WFC Return   -0.238223
# dtype: float64

# %%
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BAC Return    0.036647
# C Return      0.038672
# GS Return     0.025390
# JPM Return    0.027667
# MS Return     0.037819
# WFC Return    0.030238
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %%
sns.displot(returns.loc['2015-01-01':'2015-12-31']['MS Return'], color='green', bins=50)

# %%
sns.displot(returns.loc['2008-01-01':'2008-12-31']['C Return'], color='red', bins=50)

# %%
import plotly
import plotly.offline as py
import plotly.graph_objs as go
from plotly.offline import plot, iplot, download_plotlyjs, init_notebook_mode
import cufflinks as cf
cf.go_offline()
plotly.offline.init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
import plotly.io as pio
pio.renderers
# Out:
# Renderers configuration
# -----------------------
#     Default renderer: 'plotly_mimetype+notebook_connected'
#     Available renderers:
#         ['plotly_mimetype', 'jupyterlab', 'nteract', 'vscode',
#          'notebook', 'notebook_connected', 'kaggle', 'azure', 'colab',
#          'cocalc', 'databricks', 'json', 'png', 'jpeg', 'jpg', 'svg',
#          'pdf', 'browser', 'firefox', 'chrome', 'chromium', 'iframe',
#          'iframe_connected', 'sphinx_gallery', 'sphinx_gallery_png']

# %%
pio.renderers.default = 'colab'

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick,figsize=(12,4))
plt.legend()

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').iplot()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3639eba7-1cac-4124-a6c8-b953d7d5cd9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
plt.figure(figsize=(12,4))
BAC['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label = '30 day MV average')
BAC['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC Close')
plt.legend()

# %%
sns.heatmap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), annot=True, cmap='Blues')
# Out:
# <Axes: xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
sns.clustermap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), annot=True, cmap='Blues')

# %%
close_corr = bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr()

# %%
close_corr.iplot(kind='heatmap', colorscale='rdylbu')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fe2eb633-46be-4e14-a4a9-b682be8da891" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
bac_2015 = bank_stocks.loc['2015-01-01':'2016-01-01']['BAC']

# %%
bac_2015.iplot(kind='candle')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="606c6446-fea9-454b-9970-8b8c3edcbab3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
bank_stocks
# Out:
# Bank Ticker        BAC                                                        \
# Stock Info        Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03   46.919998  47.180000  46.150002  47.080002  31.750559  16296700
# 2006-01-04   47.000000  47.240002  46.450001  46.580002  31.413370  17757900
# 2006-01-05   46.580002  46.830002  46.320000  46.639999  31.453825  14970700
# 2006-01-06   46.799999  46.910000  46.349998  46.570000  31.406618  12599800
# 2006-01-09   46.720001  46.970001  46.360001  46.599998  31.426861  15619400
# ...                ...        ...        ...        ...        ...       ...
# 2015-12-24   17.320000  17.379999  17.219999  17.270000  14.364416  29369400
# 2015-12-28   17.219999  17.230000  16.980000  17.129999  14.247962  41777500
# 2015-12-29   17.250000  17.350000  17.160000  17.280001  14.372734  45670400
# 2015-12-30   17.200001  17.240000  17.040001  17.049999  14.181428  35066400
# ...

# %%
ms_2015 = bank_stocks.loc['2015']['MS']['Close']

# %%
ms_2015.ta_plot(study='sma', periods=[13, 21, 55])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8b5cd7a3-c18e-401a-a467-93f1ff25902d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
bac_boll = bank_stocks.loc['2015']['BAC']['Close']

# %%
bac_boll.ta_plot(study='boll')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b5de8598-652f-41d6-bf75-c565e4678c37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
